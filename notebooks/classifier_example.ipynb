# %%
from transformers import pipeline
from tqdm import tqdm
import pandas as pd
tqdm.pandas()

REP_ID = "Sandrro/cc-model"

def category_predictor(text, classifier):
    pred = pd.DataFrame(classifier(text, top_k=3))
    classifier.call_count = 0
    cats = ', '.join(pred['label'].tolist())
    probs = ', '.join(pred['score'].round(3).astype(str).tolist())
    return [cats, probs]

def classify_text(path_to_excel):
    classifier = pipeline("text-classification", model=REP_ID, tokenizer=REP_ID, max_length=2048, truncation=True, device=0)
    df_predict = pd.read_excel(path_to_excel)
    df_predict[['cats','probs']] = pd.DataFrame(df_predict['Текст'].progress_map(lambda x: category_predictor(x, classifier)).to_list())
    df_predict['category'] = df_predict.cats.map(lambda x: x.split(', ')[0])
    df_predict['probability'] = df_predict.probs.map(lambda x: float(x.split(', ')[0]))

    return df_predict

# %%
import geopandas as gpd
import numpy as np

# %%
df_predict = gpd.read_file(path_to_file)

# %%
df_predict = df_predict.set_crs(32636, allow_override=True).to_crs(4326)

# %%
df_predict.rename(columns={'Текст комментария':'Текст'}, inplace=True)

# %%
classifier = pipeline("text-classification", model=REP_ID, tokenizer='cointegrated/rubert-tiny2', max_length=2048, truncation=True, device=0)
df_predict[['cats','probs']] = pd.DataFrame(df_predict['Текст'].progress_map(lambda x: category_predictor(x, classifier)).to_list())
df_predict['category'] = df_predict.cats.map(lambda x: x.split(', ')[0])
df_predict['probability'] = df_predict.probs.map(lambda x: float(x.split(', ')[0]))
# Out:
# 100%|██████████| 2500/2500 [00:31<00:00, 80.01it/s]

# %%
import requests
import osm2geojson
OVERPASS_URL = "https://overpass-api.de/api/interpreter"
city_name = 'Санкт-Петербург'
city_admin_level = 5
buffer_size = 5
overpass_query = f"""
                            [out:json];
                                    area['name'='{city_name}']->.searchArea;
                                    (
                                    relation["admin_level"="{city_admin_level}"](area.searchArea);
                                    );
                            out geom;
                            """
result = requests.get(OVERPASS_URL, params={"data": overpass_query}, timeout=600).json()  # pylint: disable=missing-timeout
resp = osm2geojson.json2geojson(result)
if resp["features"]:
    entity_geometry = gpd.GeoDataFrame.from_features(resp["features"]).set_crs(4326).to_crs(32636)
    entity_geometry = entity_geometry[["id", "geometry"]]
    # Output geometry in any case must be some king of Polygon, so it could be extracted from city's geometry
    entity_geometry = entity_geometry.loc[entity_geometry["geometry"].geom_type.isin([
        "Polygon", "MultiPolygon", "LineString", "MultiLineString"])]
    # Buffer geometry in case of line-kind objects like waterways, roads or railways
    if buffer_size:
        entity_geometry["geometry"] = entity_geometry["geometry"].buffer(buffer_size)

city_geometry = entity_geometry
city_geometry = city_geometry.dissolve()

# %%
import osmnx as ox
roads_geometry = ox.graph_from_polygon(city_geometry.to_crs(4326).geometry.item(), network_type="drive")
roads_geometry = ox.utils_graph.graph_to_gdfs(roads_geometry, nodes=False)
roads_geometry = (roads_geometry.reset_index(level=[0, 1]).reset_index(drop=True).to_crs(32636))
roads_geometry = roads_geometry[["geometry"]]
roads_geometry_buffer = roads_geometry.copy()
roads_geometry_buffer["geometry"] = roads_geometry_buffer["geometry"].buffer(5).to_crs(4326)

# %%
street_geom = roads_geometry_buffer.sjoin(df_predict)
street_geom = street_geom.join(roads_geometry['geometry'].to_crs(4326), rsuffix = '_line')
street_geom.index = street_geom.index_right

# %%
df_predict = pd.DataFrame(df_predict)
df_predict = df_predict.join(street_geom['geometry_line'])

# %%
import json
import shapely

# %%
df_predict = df_predict.reset_index(drop=True).reset_index()

# %%
df_predict['geometry'] = df_predict['geometry'].map(lambda x: json.dumps(shapely.geometry.mapping(x)))

# %%
df_predict = df_predict.drop(columns='geometry_line').join(gpd.GeoDataFrame(df_predict[df_predict['geometry_line'].notna()], geometry='geometry_line')['geometry_line']
    .map(lambda x: json.dumps(shapely.geometry.mapping(x))))

# %%
df_predict.loc[df_predict['geometry_line'].notna(), 'geometry'] = df_predict['geometry_line']

# %%
df_predict.loc[df_predict['address'].isna(), 'geometry'] = None

# %%
df_predict['cats'] = df_predict['cats'].str.split(', ')

# %%
df_predict['probs'] = df_predict['probs'].str.split(', ')

# %%
df_predict = df_predict[['index', 'Дата и время', 'Текст', 'address', 'cats', 'probs', 'geometry']]

# %%
df_predict.rename(columns={'index':'id', 'Дата и время':'created_at', 'Текст':'text', 'address':'street_name', 'cats':'name', 'probs':'probability'}, inplace=True)

# %%
df_predict = df_predict.copy(deep=True)

# %%
rec_locs = df_predict.drop_duplicates(subset=['id', 'created_at', 'text'])[['street_name', 'geometry']]
rec_locs['probability'] = 0.7

# %%
df_predict = df_predict.explode(column=['name', 'probability'])

# %%
df_predict['probability'] = df_predict['probability'].astype(float)

# %%
df_predict = df_predict.groupby(['id', 'created_at', 'text']).apply(lambda x: x[['name', 'probability']].to_dict(orient='records')).reset_index().rename(columns={0:'recognition_blocks'})

# %%
df_predict['recognition_themes'] = [[] for x in range(len(df_predict))]

# %%
df_predict['recognition_locations'] = [[x] for x in rec_locs.to_dict(orient='records')]

# %%
df_predict['approved_block'] = 'block'
df_predict['approved_theme'] = 'theme'
df_predict['approved_location'] = None

# %%
df_predict.drop_duplicates(subset=['text', 'created_at'], inplace=True)

# %%
import json

# %%
df_predict.to_json('recognition_example.json', orient='records')

# %%
json.loads(df_predict.to_json(orient='records'))
# Out:
# [{'id': 0,
#   'created_at': '2022.12.13 14:34',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], невский 173-175',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.357},
#    {'name': 'Благоустройство', 'probability': 0.234},
#    {'name': 'БОС', 'probability': 0.215}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'невский 173-175',
#     'geometry': '{"type": "Point", "coordinates": [30.382917999999997, 59.92417199999997]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1,
#   'created_at': '2019.09.27 10:27',
#   'text': 'Невский 184 отопления НЕТ Аварий никаких нет 😕',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.703},
#    {'name': 'Энергетика', 'probability': 0.269},
#    {'name': 'Дороги', 'probability': 0.008}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский 184',
#     'geometry': '{"type": "Point", "coordinates": [30.384049999999995, 59.92437]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id':
],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 13,
#   'created_at': '2019.10.14 22:04',
#   'text': '[club129587345|Дом купца Овсянникова (Ул.Херсонская, 2/9)], у нас тоже проблема с подвалом, сейчас они пытаются увеличить мощность на это помещение, ждём протокола осс, надеюсь не поддельного. Так же выяснили, что сделан незаконный выход на Невский проспект с подвала, вот просто взяли и прорубили вместо окна дверь в историческом фасаде дома.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.863},
#    {'name': 'Строительство', 'probability': 0.084},
#    {'name': 'БОС', 'probability': 0.016}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 14,
#   'created_at': '2020.10.14 10:34',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], ни горячей воды, ни отопления нет со вчера. Как днём выключили, так и не дали, тогда зачем испытание запланировано на сегодня, если вчера вырубать начали, это норм? Когда дадут воду? Невский пр.103.',
#   'recognition_blocks': [{'name': 'Энергетика', 'probability': 0.961},
#    {'name': 'ЖКХ', 'probability': 0.029},
#    {'name': 'Дороги', 'probability': 0.002}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 15,
#   'created_at': '2022.02.01 02:59',
#   'text': 'Невский,  95, первый двор, огромная шапка снега над входом в третью парадную. Кому-то не повезёт.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.922},
#    {'name': 'Дороги', 'probability': 0.042},
#    {'name': 'Не ЦУР', 'probability': 0.015}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 16,
#   'created_at': '2020.10.11 04:03',
#   'text': '[id589844771|Елизавета], а у нас вместо холодной из всех труб горячая льется.  Уже месяц.  Невский, 95. ЖКС 3. Разгильдяи!',
#   'recognition_blocks': [{'name': 'Энергетика', 'probability': 0.745},
#    {'name': 'ЖКХ', 'probability': 0.222},
#    {'name': 'БОС', 'probability': 0.009}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 17,
#   'created_at': '2022.03.04 21:59',
#   'text': 'Невский пр. д. 97 во дворе мусор уже как 3 дня лежит.',
#   'recognition_blocks': [{'name': 'ТКО', 'probability': 0.969},
#    {'name': 'Благоустройство', 'probability': 0.012},
#    {'name': 'ЖКХ', 'probability': 0.011}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 18,
#   'created_at': '2022.02.06 18:14',
#   'text': 'Невский, 95. Обещали убрать снег с крыш до конца прошедшей недели в ответ на моё  обращение.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.896},
#    {'name': 'Энергетика', 'probability': 0.053},
#    {'name': 'Дороги', 'probability': 0.033}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 19,
#   'created_at': '2022.02.03 18:06',
#   'text': 'Невский, 95. Вторые сутки без отопления. Отключили   2 февраля в 11 часов, обещали включить в 7  часов 3.02. Теперь  выясняется, что до 21 часа  ни горячей воды ни отопления не будет.  И дадут ли в 21 час неизвестно. У моей семьи ковид. Вынуждены сидеть  в холоде. На улице - 10. Потом счёт вломят по полной, как всегда бывает у ЖКС-3.',
#   'recognition_blocks': [{'name': 'Энергетика', 'probability': 0.527},
#    {'name': 'ЖКХ', 'probability': 0.44},
#    {'name': 'Образование', 'probability': 0.007}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 20,
#   'created_at': '2021.11.06 17:36',
#   'text': '[club189353983|Промышленность, инновации и торговля Петербурга], включите пожалуйста в план проверок адрес Невский проспект дом 63, вчера Угрюмка работала всю ночь и ее посетители всю ночь орали и пели во дворе дома.',
#   'recognition_blocks': [{'name': 'БОС', 'probability': 0.988},
#    {'name': 'Не ЦУР', 'probability': 0.007},
#    {'name': 'ЖКХ', 'probability': 0.001}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 21,
#   'created_at': '2022.02.05 14:33',
#   'text': 'Вот бы в план объезда включили адрес: Невский пр. 107! Вроде и не далеко ехать от администрации, но как-то все не удаётся заглянуть на огонёк. ЖКС-3, с середины января, как насугробили весь двор, так "воз и ныне там". Хотя несколько раз развешивали объявления ч требованием убрать авто, для вывоза снега, но видимо вывозили для отчёта на бумаге. Скоро во двор, из-за сугробов, можно будет заехать или на тракторе, или на танке.',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.823},
#    {'name': 'ЖКХ', 'probability': 0.1},
#    {'name': 'Не ЦУР', 'probability': 0.028}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 22,
#   'created_at': '2019.05.08 10:05',
#   'text': 'Подскажите, на Невский проспект зрителей во время Бессмертного полка тоже через рамки будут пускать или рамки для прохода в полк???И в том году шли с детскими самокатами. Сейчас через рамки пропустят???',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.864},
#    {'name': 'Транспорт', 'probability': 0.078},
#    {'name': 'Дороги', 'probability': 0.013}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 23,
#   'created_at': '2020.09.16 13:00',
#   'text': '[id628444|Настя Караваева], здравствуйте! ГБОУ гимназия № 168 в 2019 заключила году договор на разработку проектно-сметной документации по ремонту спортивной площадки, расположенной по адресу: Невский пр., д. 169, литер А, со сроком выполнения работ - август 2020 года. После согласования проектно-сметной документации в уполномоченном органе будет рассмотрена возможность включения работ по ремонту спортивной площадки в Адресную программу капитального ремонта образовательных учреждений на 2021-2023 годы. Данные работы будут выполнены после получения необходимого финансирования.',
#   'recognition_blocks': [{'name': 'Строительство', 'probability': 0.721},
#    {'name': 'Благоустройство', 'probability': 0.166},
#    {'name': 'Образование', 'probability': 0.077}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 24,
#   'created_at': '2022.02.01 18:04',
#   'text': '[id516449357|Галина Трусова], здравствуйте! Мы понимаем Ваше волнение, поэтому направили Ваше сообщение в работу управляющей организации, на адресу Невский пр., д.95 выставлены ограждения, сброс снега и наледи с кровли будет выполнен до конца недели. Приносим извинения за предоставленные неудобства.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.966},
#    {'name': 'Дороги', 'probability': 0.01},
#    {'name': 'Не ЦУР', 'probability': 0.006}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 25,
#   'created_at': '2021.12.18 22:30',
#   'text': 'Теперь надо улицы помыть!! Хотя б Невский проспект, дорогие вы наши. Надеемся хоть не много у вас осталось уважение к себе и гражданам города.',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.904},
#    {'name': 'ЖКХ', 'probability': 0.046},
#    {'name': 'Не ЦУР', 'probability': 0.018}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 26,
#   'created_at': '2022.09.29 18:13',
#   'text': 'Добрый вечер. Невский проспект, дом 160. Тепла нет до сих пор, очень мерзнем. Звонили по 004, сказали, что еще нет распоряжения. Но, даже периодического протапливания не было!',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.934},
#    {'name': 'Энергетика', 'probability': 0.026},
#    {'name': 'Дороги', 'probability': 0.015}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 27,
#   'created_at': '2021.12.24 21:30',
#   'text': '[id146942095|Рональд], Невский пр., убирают сутками, как и другие улицы., Вы просто не были там и не видели в живую.',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.474},
#    {'name': 'ЖКХ', 'probability': 0.293},
#    {'name': 'Благоустройство', 'probability': 0.11}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 28,
#   'created_at': '2021.12.15 11:01',
#   'text': 'Невский проспект не создаёт праздника! Да, новые декорации...но их пять штук, три горят))) А эти крылья стрекозы или что....мило, но не то',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.611},
#    {'name': 'Строительство', 'probability': 0.166},
#    {'name': 'Энергетика', 'probability': 0.06}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 29,
#   'created_at': '2022.02.07 07:40',
#   'text': 'Невский, 95. Замучали с отключением отопления. Отключили первый раз   2 февраля в 11 часов, обещали включить в 7  часов 3.02. Потом выяснилось, что до 21 часа  ни горячей воды ни отопления не будет.  И дадут ли в 21 час неизвестно. У моей семьи ковид. Вынуждены сидеть  в холодной квартире. На улице было - 10.  Вчера опять отключили в 11 часов, обещали подключить в 4 утра. Не подключили. 004 сказали, что до 11 утра. Ждём. Потом счёт вломят по полной, как всегда бывает у ЖКС-3.',
#   'recognition_blocks': [{'name': 'Энергетика', 'probability': 0.907},
#    {'name': 'ЖКХ', 'probability': 0.076},
#    {'name': 'Здравоохранение', 'probability': 0.003}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 30,
#   'created_at': '2022.02.07 07:14',
#   'text': 'Невский,  95 Было, стало. Это над входом в парадную!',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.668},
#    {'name': 'Не ЦУР', 'probability': 0.248},
#    {'name': 'БОС', 'probability': 0.025}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 31,
#   'created_at': '2020.03.31 19:21',
#   'text': '[id438522071|Ольга], двор у нас очень грязный. Невский, 95.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.89},
#    {'name': 'Дороги', 'probability': 0.065},
#    {'name': 'Не ЦУР', 'probability': 0.012}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 32,
#   'created_at': '2022.05.11 15:28',
#   'text': '[id516449357|Галина], мы уточнили у коллег, дом по адресу Невский проспект, 95 обслуживает домофонная компания  Наш домофон. Обратитесь к ним по номеру телефона: 8(812)633-36-20',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.937},
#    {'name': 'БОС', 'probability': 0.015},
#    {'name': 'Не ЦУР', 'probability': 0.014}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 33,
#   'created_at': '2019.08.12 12:47',
#   'text': 'Подскажите пожалуйста , Невский проспект 163 , можно покрасить фасад , и отремонтировать кровлю , протечки каждую зиму !',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.928},
#    {'name': 'Энергетика', 'probability': 0.018},
#    {'name': 'Дороги', 'probability': 0.016}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 34,
#   'created_at': '2022.12.14 15:02',
#   'text': 'Невский пр. сегодня 14.12.22 в 14:00!!! Кто чего у вас убирает?! Сталина на вас всех нет! Лес бы валить вредителей отправил!',
#   'recognition_blocks': [{'name': 'Экология', 'probability': 0.697},
#    {'name': 'ТКО', 'probability': 0.249},
#    {'name': 'Благоустройство', 'probability': 0.032}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 35,
#   'created_at': '2021.06.22 16:03',
#   'text': 'Уважаемая, [id200275088|Герасимова Галина]! Еще раз хотим повторить, направьте нам свои данные и будем запрашивать в социальной защите ответ и смотреть, что можно сделать. Спасибо! Подойти на прием можно по адресу: Невский пр., д. 176, "Открытый район" часы работы с понедельника по четверг с 9,00 до 18,00, пятница с 9,00 до 17,00. При себе иметь паспорт заявителя.',
#   'recognition_blocks': [{'name': 'СоцЗащита', 'probability': 0.844},
#    {'name': 'Не ЦУР', 'probability': 0.113},
#    {'name': 'БОС', 'probability': 0.011}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 36,
#   'created_at': '2022.12.13 17:53',
#   'text': 'Уважаемая Администрация Центрального района!, сегодня силами жильцов был очищен двор по адресу Невский проспект дом 61. Дворников так и не увидели.  Ну и ладно, зарплату не просим  Можно ли посодействовать в очистке крыши нашего дома. Чистить нашу крышу легко, доступ обеспечим.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.909},
#    {'name': 'Энергетика', 'probability': 0.037},
#    {'name': 'Строительство', 'probability': 0.022}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 37,
#   'created_at': '2019.05.08 08:53',
#   'text': 'А зрители тоже через рамки будут проходить, что ли? Или зрителей в этом году вообще не пустят на Невский проспект,?',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.908},
#    {'name': 'Строительство', 'probability': 0.025},
#    {'name': 'Дороги', 'probability': 0.015}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 38,
#   'created_at': '2021.12.15 07:19',
#   'text': 'Мой двор. Невский, 95.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.956},
#    {'name': 'Дороги', 'probability': 0.013},
#    {'name': 'Не ЦУР', 'probability': 0.008}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 39,
#   'created_at': '2019.05.08 23:27',
#   'text': 'А Невский проспект мы сможем перейти? Он же какими-то рамками будет перекрыт.',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.595},
#    {'name': 'Энергетика', 'probability': 0.167},
#    {'name': 'Транспорт', 'probability': 0.066}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 40,
#   'created_at': '2022.12.12 14:35',
#   'text': 'Скажите,  пожалуйста,  почему не все новогодние украшения "горят" на Старо-Невском? Например, возле дома Невский, 93.',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.325},
#    {'name': 'БОС', 'probability': 0.316},
#    {'name': 'Строительство', 'probability': 0.168}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 41,
#   'created_at': '2022.12.26 15:37',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], там адрес на этом графике виден. Невский, 95 , 3-я парадная.',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.782},
#    {'name': 'Дороги', 'probability': 0.082},
#    {'name': 'ЖКХ', 'probability': 0.039}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 42,
#   'created_at': '2019.08.05 19:19',
#   'text': 'Я предлагаю еще один адрес добавить для раздельного сбора мусора - Невский пр.176. Там, кстати и удобная площадка есть',
#   'recognition_blocks': [{'name': 'ТКО', 'probability': 0.99},
#    {'name': 'Благоустройство', 'probability': 0.004},
#    {'name': 'Экология', 'probability': 0.001}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 43,
#   'created_at': '2022.05.11 15:51',
#   'text': '[id516449357|Галина Трусова], здравствуйте!  Уважаемая Галина! По Вашему адресу: Невский пр-т, д. 95 предусмотрено размещение устройств мониторинга на входах в парадные многоквартирных домов, в рамках проекта «Умный двор». В Вашем доме в парадных № 3 и № 4 размещением оборудованием занималось АО «ЭР-Телеком Холдинг» 03.11.2022. В Вашем доме размещена многоабонентская домофонная панель. Работы проведены в порядке модернизации существующего домофонного оборудования.  По вопросу ремонта домофонного оборудования (магнитный замок / доводчик, кнопка входа, абонентское оборудование) необходимо обратиться в организацию, обслуживающую домофонное оборудование: ООО «ДКР», тел. 633-36-20.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.887},
#    {'name': 'Строительство', 'probability': 0.043},
#    {'name': 'Не ЦУР', 'probability': 0.034}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 44,
#   'created_at': '2022.02.07 21:07',
#   'text': 'Добрый вечер, если можно так сказать. Проживаю по адресу невский д. 97. В настоящее время с крыши не убран снег и лед. Снег со льдом летит с крыши, по всей видимости жск 3  выжидает когда снег весь растает и лед  упадет, после этого сделают пару снимков что все убрали. Только даты в объявлении меняют сначала 02.02, потом 03.02, сейчас 08.02... а снег как лежал так и лежит. Фотографии есть могу предоставить только что сфотографировано.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.878},
#    {'name': 'Дороги', 'probability': 0.033},
#    {'name': 'Энергетика', 'probability': 0.033}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 45,
#   'created_at': '2020.10.11 04:06',
#   'text': '[id61434865|Виталий], Невский, 95- Гончарная, 10. Ужасные дворы!',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.754},
#    {'name': 'Строительство', 'probability': 0.107},
#    {'name': 'Не ЦУР', 'probability': 0.043}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 46,
#   'created_at': '2022.02.07 07:48',
#   'text': 'Невский, 95 БЫЛО, СТАЛО',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.442},
#    {'name': 'Строительство', 'probability': 0.366},
#    {'name': 'БОС', 'probability': 0.099}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 47,
#   'created_at': '2022.08.01 16:14',
#   'text': '[id1306022|Наталья], здравствуйте! Прием документов для включения квартиры в перечень коммунальных квартир, подлежащих расселению, ведётся в администрации Центрального района Санкт-Петербурга по адресу: Невский пр., д. 176 по понедельникам и средам с 9:00 до 13:00, с 14:00 до 18:00.  После утверждения административного регламента будет возможна подача документов через многофункциональные центры предоставления государственных услуг.   При возникновении вопросов Вы можете обращаться в жилищный отдел по телефону: 417-46-03',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.759},
#    {'name': 'Строительство', 'probability': 0.199},
#    {'name': 'ТКО', 'probability': 0.008}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 48,
#   'created_at': '2021.12.15 07:27',
#   'text': 'Невский проспект!!!!!',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.652},
#    {'name': 'ЖКХ', 'probability': 0.073},
#    {'name': 'Энергетика', 'probability': 0.072}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 49,
#   'created_at': '2021.12.01 11:09',
#   'text': '[id602398921|Ярослав Костров], здравствуйте! Понимаем Ваше беспокойство, сотрудники администрации в рамках своих полномочий проверили предприятие по адресу Невский проспект, д. 180. В настоящее время ведется работа в рамках административного производства в отношении руководителя ярмарки за  осуществление деятельности без QR-кода. Благодарим за активную гражданскую позицию.',
#   'recognition_blocks': [{'name': 'БОС', 'probability': 0.911},
#    {'name': 'Не ЦУР', 'probability': 0.071},
#    {'name': 'Строительство', 'probability': 0.004}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 50,
#   'created_at': '2022.09.13 19:28',
#   'text': 'Что вы врёте про ежедневное мытьё дворов. Невский, 95. Дворы не мыли ни разу, даже после зимы. На контейнерной площадке постоянные чёрные пятна. В арке с Невского грязь, песок окурки и пыль. Дворы все в голубином помёте.',
#   'recognition_blocks': [{'name': 'ТКО', 'probability': 0.476},
#    {'name': 'ЖКХ', 'probability': 0.208},
#    {'name': 'Дороги', 'probability': 0.164}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 51,
#   'created_at': '2021.12.01 11:07',
#   'text': '[id602398921|Ярослав Костров], здравствуйте! Понимаем Ваше беспокойство, сотрудники администрации в рамках своих полномочий проверили предприятие по адресу Невский проспект, д. 180. В настоящее время ведется работа в рамках административного производства в отношении руководителя ярмарки за  осуществление деятельности без QR-кода. Благодарим за активную гражданскую позицию.',
#   'recognition_blocks': [{'name': 'БОС', 'probability': 0.911},
#    {'name': 'Не ЦУР', 'probability': 0.071},
#    {'name': 'Строительство', 'probability': 0.004}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 52,
#   'created_at': '2022.12.12 12:31',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], Невский пр., 136, литера Б',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.547},
#    {'name': 'Строительство', 'probability': 0.131},
#    {'name': 'БОС', 'probability': 0.131}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 53,
#   'created_at': '2019.06.20 16:27',
#   'text': 'Уважаемый Максим Семёнович! Отдел по работе с собственниками Жилкомсервиса 2 всячески препятствует созданию Совета дома по адресу Невский проспект д 61. Желание у владельцев жилых и нежилых помещений присутствует, куда нам обращаться?',
#   'recognition_blocks': [{'name': 'Строительство', 'probability': 0.706},
#    {'name': 'ЖКХ', 'probability': 0.242},
#    {'name': 'Не ЦУР', 'probability': 0.021}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 54,
#   'created_at': '2019.06.20 17:39',
#   'text': 'Поздравляю, конечно. Пять лет назад первый и последний раз приехал в МФЦ на Невский проспект, надо было поменять паспорт. Просидел два часа в очереди, плюнул и поехал за 2000 рублей или что-то вроде этого поменял паспорт за несколько минут. Надеюсь, за пять лет все изменилось в лучшую сторону.',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.683},
#    {'name': 'Транспорт', 'probability': 0.186},
#    {'name': 'БОС', 'probability': 0.043}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 55,
#   'created_at': '2022.12.10 17:42',
#   'text': '[club143265175|Центральный район Санкт-Петербурга],  Здравствуйте.  Невский, 95, 3-я парадная.',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.729},
#    {'name': 'ЖКХ', 'probability': 0.096},
#    {'name': 'БОС', 'probability': 0.06}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 56,
#   'created_at': '2022.09.29 12:34',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], Невский пр. 175',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.41},
#    {'name': 'Благоустройство', 'probability': 0.244},
#    {'name': 'БОС', 'probability': 0.105}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 57,
#   'created_at': '2021.01.19 00:19',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], я в восторге!  ЖКС 3 Центрального района работает с опережением графика. Сегодня 18 число, а в графике уборки крестик стоит уже за 19. Главное прибкжать, крестиков наставить, можно и не убирать! Это при том, что в морозные дни было относительно чисто на улице и парадная в частой уборке не нуждалась. Не убран снег и во дворах. Только расчищена дорожка, чтобы  ящики с мусором по двору таскать. Невский, 95 3-я парадная.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.755},
#    {'name': 'Дороги', 'probability': 0.174},
#    {'name': 'Благоустройство', 'probability': 0.035}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 58,
#   'created_at': '2020.12.29 17:52',
#   'text': 'Скажите, пожалуйста, мы так и войдём в Новый год с неработающим лифтом. Невский, 95, 3-й подъезд. Лифт стоит с 25 декабря. Обслуживающая организация отвечает, что по возможности отремонтируют. Как это понимать?',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.974},
#    {'name': 'Не ЦУР', 'probability': 0.005},
#    {'name': 'Строительство', 'probability': 0.005}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 59,
#   'created_at': '2020.12.29 17:49',
#   'text': 'Невский проспект, дом 95. Второй двор : к мусорным контейнерам не подойти - гололёд. Залита льдом и крышка канализационного колодца.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.532},
#    {'name': 'Энергетика', 'probability': 0.351},
#    {'name': 'ТКО', 'probability': 0.058}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 60,
#   'created_at': '2022.12.12 23:45',
#   'text': 'Уважаемая администрация! Скажите,  пожалуйста,  почему не все новогодние украшения "горят" на Старо-Невском? Например, возле дома Невский, 93. А на Невском от Дома Актёра, Невский, 92-94 до площади Восстания не горят 4 гирлянды.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.484},
#    {'name': 'Энергетика', 'probability': 0.168},
#    {'name': 'Строительство', 'probability': 0.125}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 61,
#   'created_at': '2022.11.15 17:23',
#   'text': 'Почему Невский проспект от Восстания до Литейного заклеен рекламой борделей? Это лицо города для приезжих!',
#   'recognition_blocks': [{'name': 'Не ЦУР', 'probability': 0.613},
#    {'name': 'БОС', 'probability': 0.332},
#    {'name': 'Дороги', 'probability': 0.015}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Невский',
#     'geometry': '{"type": "Point", "coordinates": [30.380439, 59.924276]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 62,
#   'created_at': '2019.07.06 14:55',
#   'text': 'Показателен пример реконструкция лифтов на Тележной улице. Сначала реконструировали, а потом дома расселили',
#   'recognition_blocks': [{'name': 'Строительство', 'probability': 0.525},
#    {'name': 'ЖКХ', 'probability': 0.358},
#    {'name': 'Не ЦУР', 'probability': 0.049}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Тележной',
#     'geometry': '{"type": "LineString", "coordinates": [[30.3776121, 59.92489860000001], [30.3774751, 59.9249503], [30.376948, 59.925149200000014], [30.376926200000003, 59.92515750000001]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 64,
#   'created_at': '2020.03.31 21:44',
#   'text': '[id14026782|Светлана Мишачкова], здравствуйте! Решение об отмене торгов по продаже единым лотом жилых и нежилых помещений, расположенных по адресам: Тележная ул., д.21, лит А: д.23, лит А: д.25-27, лит А: д.29, лит А и лит Г, назначенных на 30.04.2020, было принято вследсвие представленной Службой Госстройнадзора Санкт-Петербурга информации о результатах геотехнического мониторинга, свидетельствующих об ухудшающемся состоянии и возможном самообрушении конструкций.',
#   'recognition_blocks': [{'name': 'БОС', 'probability': 0.95},
#    {'name': 'Не ЦУР', 'probability': 0.029},
#    {'name': 'ЖКХ', 'probability': 0.008}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Тележная',
# ...
#   'approved_location': None},
#  {'id': 1376,
#   'created_at': '2022.12.11 16:46',
#   'text': 'Джамбула 19. Бардак полный. Баки оставляют во дворе перед парадной и не выкапывают.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.409},
#    {'name': 'ТКО', 'probability': 0.274},
#    {'name': 'Благоустройство', 'probability': 0.165}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Джамбула 19',
#     'geometry': '{"type": "Point", "coordinates": [30.336547, 59.924596000000015]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1377,
#   'created_at': '2022.12.11 16:45',
#   'text': 'Джамбула 19, два дня баки стояли в арке дома, перегораживая проезд машинам. В итоге мужчины нашего двора объединились и сами выкатили баки на улицу. Но кто их обратно закатит? Кто и когда приберет двухдневные кучи мусора на мусорной площадке?  Почему ЖЭК отныне считает, что это не их обязанности?',
#   'recognition_blocks': [{'name': 'ТКО', 'probability': 0.988},
#    {'name': 'Благоустройство', 'probability': 0.004},
#    {'name': 'БОС', 'probability': 0.002}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Джамбула 19',
#     'geometry': '{"type": "Point", "coordinates": [30.336547, 59.924596000000015]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1378,
#   'created_at': '2020.12.19 12:31',
#   'text': 'Бородинская улица. Сегодня весь день и ближайшие дни плюсовая температура!!!!! Зачем ???!!!!',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.506},
#    {'name': 'Энергетика', 'probability': 0.321},
#    {'name': 'ЖКХ', 'probability': 0.061}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Бородинская',
#     'geometry': '{"type": "LineString", "coordinates": [[30.330483700000002, 59.926072200000014], [30.3305877, 59.92598909999999], [30.3308298, 59.925874599999986], [30.3309076, 59.9258379], [30.331522300000003, 59.9255472], [30.3323732, 59.925139399999985], [30.332822300000004, 59.924932599999984], [30.3337222, 59.92450710000001], [30.3339011, 59.924422499999984], [30.3341624, 59.924299000000005], [30.334524499999997, 59.92412770000001], [30.334910400000002, 59.92394529999999], [30.335278900000002, 59.923771], [30.3356086, 59.9236152], [30.3357379, 59.923553999999996]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1379,
#   'created_at': '2022.03.12 09:04',
#   'text': 'И на Лиговский 135 ) у нас тут и графити имеется во всем дворе на 4 дома и ворота погнутые и козырьки отсутствующие над парадными, в общем весь набор. И лёд есть в достатке.',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.876},
#    {'name': 'Дороги', 'probability': 0.042},
#    {'name': 'Не ЦУР', 'probability': 0.034}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Лиговский 135',
#     'geometry': '{"type": "Point", "coordinates": [30.351558000000004, 59.91748399999999]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1380,
#   'created_at': '2020.06.28 01:41',
#   'text': 'Лиговский 135, снова полетел свет на внутри домовой территории, плюс те накладки которые недавно поставили частично сорвали. Разберитесь пожалуйста. Лампы не работают рядом с входами в парадные, а также в арке и на протяжении всего двора. Горят только 2 фонаря из больших и пара маленьких',
#   'recognition_blocks': [{'name': 'Энергетика', 'probability': 0.975},
#    {'name': 'ЖКХ', 'probability': 0.015},
#    {'name': 'Дороги', 'probability': 0.002}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Лиговский 135',
#     'geometry': '{"type": "Point", "coordinates": [30.351558000000004, 59.91748399999999]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1381,
#   'created_at': '2020.02.19 14:23',
#   'text': '[id17151132|Анна], лиговский 127, лиговский 93 тоже площадки. А вообще в этом районе действительно плотная застройка, мест мало. Мы в конце прошлого года делали большой опрос, такие пожелания уже звучали от жителей по всем перечисленным вами поводам. Будем стараться в ближайшие сроки поменять ситуацию',
#   'recognition_blocks': [{'name': 'Благоустройство', 'probability': 0.793},
#    {'name': 'Строительство', 'probability': 0.165},
#    {'name': 'Дороги', 'probability': 0.01}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'лиговский 127',
#     'geometry': '{"type": "Point", "coordinates": [30.351909, 59.918011]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1382,
#   'created_at': '2022.02.22 10:43',
#   'text': '[id338851|Дмитрий], Лиговский 116 ни разу с начала зимы не убирали((',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.506},
#    {'name': 'Дороги', 'probability': 0.442},
#    {'name': 'Благоустройство', 'probability': 0.014}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Лиговский 116',
#     'geometry': '{"type": "Point", "coordinates": [30.353264999999997, 59.91841699999999]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1383,
#   'created_at': '2021.12.06 17:57',
#   'text': 'Остропольский переулок не чищен с самого начала снегопада. А там между прочим находится детский сад. Позорище! Наледи такие на узких тротуарах что ни пешком ни с коляской не пробраться. Обратите пожалуйста внимание на это',
#   'recognition_blocks': [{'name': 'Дороги', 'probability': 0.875},
#    {'name': 'ЖКХ', 'probability': 0.064},
#    {'name': 'Благоустройство', 'probability': 0.024}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Остропольский',
#     'geometry': '{"type": "LineString", "coordinates": [[30.3534487, 59.92006730000001], [30.3533025, 59.920090899999984], [30.3532606, 59.92009750000002], [30.3528468, 59.920164], [30.352779600000005, 59.920199599999975]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1387,
#   'created_at': '2022.02.14 15:45',
#   'text': 'Забыли зайти на Разъезжую 42/34-домоуправ не в курсе когда планирует убирать двор',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.546},
#    {'name': 'Дороги', 'probability': 0.337},
#    {'name': 'Благоустройство', 'probability': 0.057}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Разъезжую 42',
#     'geometry': '{"type": "Point", "coordinates": [30.352807, 59.92180399999998]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1388,
#   'created_at': '2022.02.25 14:45',
#   'text': 'Беглов обещал убрать наш дом Разъезжая 42 ближе к выходным. Интересно сделают или снова соврут',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.624},
#    {'name': 'Дороги', 'probability': 0.148},
#    {'name': 'Не ЦУР', 'probability': 0.101}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Разъезжая 42',
#     'geometry': '{"type": "Point", "coordinates": [30.352807, 59.92180399999998]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1389,
#   'created_at': '2022.06.06 14:45',
#   'text': 'Уважаемая Администрация Центрального района! Просьба помыть двор по ул Разъездая 42/34!',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0
]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1403,
#   'created_at': '2022.01.28 15:27',
#   'text': 'Улица Тюшина, дом 4, правая сторона дома в сторону Лиговского проспекта не очищена. Просим принять меры! Прилагаю фотографии',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.633},
#    {'name': 'Дороги', 'probability': 0.273},
#    {'name': 'Энергетика', 'probability': 0.063}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Тюшина',
#     'geometry': '{"type": "LineString", "coordinates": [[30.348472700000002, 59.917097], [30.348678000000003, 59.91706359999998], [30.3493175, 59.91695969999997], [30.349407499999998, 59.91694509999999], [30.3498227, 59.91687760000001], [30.349956, 59.916855999999996], [30.350492099999997, 59.9167689], [30.3507374, 59.91672899999998], [30.351021400000004, 59.916682800000004], [30.351141499999997, 59.91666340000002], [30.3512716, 59.916642100000004]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1407,
#   'created_at': '2022.01.28 15:34',
#   'text': 'Улица Тюшина, дом 4 Фотографии двора. Льдины не убраны!',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.792},
#    {'name': 'Дороги', 'probability': 0.138},
#    {'name': 'Энергетика', 'probability': 0.027}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Тюшина',
#     'geometry': '{"type": "LineString", "coordinates": [[30.348472700000002, 59.917097], [30.348678000000003, 59.91706359999998], [30.3493175, 59.91695969999997], [30.349407499999998, 59.91694509999999], [30.3498227, 59.91687760000001], [30.349956, 59.916855999999996], [30.350492099999997, 59.9167689], [30.3507374, 59.91672899999998], [30.351021400000004, 59.916682800000004], [30.351141499999997, 59.91666340000002], [30.3512716, 59.916642100000004]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1411,
#   'created_at': '2022.04.25 14:59',
#   'text': '[club143265175|Центральный район Санкт-Петербурга], дом, который непосредственно разрушен, находится по адресу: ул.Константина Заслонова дом 18, Спасибо',
#   'recognition_blocks': [{'name': 'Строительство', 'probability': 0.969},
#    {'name': 'Благоустройство', 'probability': 0.012},
#    {'name': 'ЖКХ', 'probability': 0.007}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Заслонова',
#     'geometry': '{"type": "LineString", "coordinates": [[30.3502902, 59.919953099999994], [30.3497455, 59.91975149999998], [30.349194499999996, 59.91955039999999], [30.3487205, 59.91936810000001], [30.348554300000004, 59.91930599999999], [30.3475981, 59.91894340000001], [30.347433, 59.9188782], [30.3467187, 59.91860530000001], [30.3466476, 59.918578199999985], [30.346257100000003, 59.91844499999997]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  {'id': 1412,
#   'created_at': '2019.10.08 07:35',
#   'text': 'Константина Заслонова 9,    К.Заслонова 26/28',
#   'recognition_blocks': [{'name': 'ЖКХ', 'probability': 0.4},
#    {'name': 'БОС', 'probability': 0.275},
#    {'name': 'Строительство', 'probability': 0.103}],
#   'recognition_themes': [],
#   'recognition_locations': [{'street_name': 'Константина',
#     'geometry': '{"type": "LineString", "coordinates": [[30.3502902, 59.919953099999994], [30.3497455, 59.91975149999998], [30.349194499999996, 59.91955039999999], [30.3487205, 59.91936810000001], [30.348554300000004, 59.91930599999999], [30.3475981, 59.91894340000001], [30.347433, 59.9188782], [30.3467187, 59.91860530000001], [30.3466476, 59.918578199999985], [30.346257100000003, 59.91844499999997]]}',
#     'probability': 0.7}],
#   'approved_block': 'block',
#   'approved_theme': 'theme',
#   'approved_location': None},
#  ...]
